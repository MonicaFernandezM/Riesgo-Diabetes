# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve

# %% [markdown]
# ## Cargando la tabla limpia

# %%
df = pd.read_csv("archive/processed/diabetes_clean.csv")

# %%
df
# Out:
#         Diabetes_012  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 0                  0       1         1          1  40.0       1       0
# 1                  0       0         0          0  25.0       1       0
# 2                  0       1         1          1  28.0       0       0
# 3                  0       1         0          1  27.0       0       0
# 4                  0       1         1          1  24.0       0       0
# ...              ...     ...       ...        ...   ...     ...     ...
# 229776             0       1         1          1  45.0       0       0
# 229777             2       1         1          1  18.0       0       0
# 229778             0       0         0          1  28.0       0       0
# 229779             0       1         0          1  23.0       0       0
# 229780             2       1         1          1  25.0       0       0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  ...  NoDocbcCost  GenHlth  \
# 0                          0             0       0  ...            0        5
# 1                          0             1       0  ...            1        3
# 2                          0             0       1  ...            1        5
# 3                          0             1       1  ...            0        2
# 4                          0             1       1  ...            0        2
# ...                      ...           ...     ...  ...          ...      ...
# 229776                     0             0       1  ...            0        3
# 229777                     0             0       0  ...            0        4
# 229778                     0             1       1  ...            0        1
# 229779                     0             0       1  ...            0        3
# 229780                     1             1       1  ...            0        2
#
#         MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  Income  Risk_Group
# 0           18.0      15.0         1    0    9          4       3           0
# 1            0.0       0.0         0    0    7          6       1           0
# 2           30.0      30.0         1    0    9          4       8           0
# 3            0.0       0.0         0    0   11          3       6           0
# 4            3.0       0.0         0    0   11          5       4           0
# ...          ...       ...       ...  ...  ...        ...     ...         ...
# 229776       0.0       5.0         0    1    5          6       7           0
# 229777       0.0       0.0         1    0   11          2       4           1
# 229778       0.0       0.0         0    0    2          5       2           0
# 229779       0.0       0.0         0    1    7          5       1           0
# 229780       0.0       0.0         0    0    9          6       2           1
#
# [229781 rows x 23 columns]

# %%
lower = df["BMI"].quantile(0.01)
upper = df["BMI"].quantile(0.99)
df["BMI"] = df["BMI"].clip(lower, upper)

# %% [markdown]
# ### Train test Split

# %%
# Creando features y target para mi modelo 
features = df.drop(["Diabetes_012","Risk_Group"], axis=1)
target= df["Risk_Group"]

# %% [markdown]
# ##### Viendo el desbalance

# %%
print(target.value_counts(normalize=True))
# Out:
# Risk_Group
# 0    0.827114
# 1    0.172886
# Name: proportion, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features, 
    target, 
    test_size=0.2, 
    stratify= target,
    random_state=42)

# %%
dt = DecisionTreeClassifier(
    random_state=42,
    max_depth=4,
    min_samples_split=10,
    class_weight="balanced"
)

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=4,
#                        min_samples_split=10, random_state=42)

# %%
#prediciendo 
y_pred = dt.predict(X_test)
y_probs = dt.predict_proba(X_test)[:,1]

print(classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_probs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78     38012
#            1       0.32      0.75      0.45      7945
#
#     accuracy                           0.69     45957
#    macro avg       0.63      0.71      0.62     45957
# weighted avg       0.82      0.69      0.72     45957
#
# ROC-AUC: 0.774388457833229

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[25616 12396]
#  [ 2009  5936]]

# %%
# Optimización de threshold (max F1)
precision, recall, thresholds = precision_recall_curve(y_test, y_probs)
f1 = 2 * (precision[:-1] * recall[:-1]) / (precision[:-1] + recall[:-1] + 1e-10)
best_threshold = thresholds[np.argmax(f1)]

best_index = np.argmax(f1)
best_threshold = thresholds[best_index]

print("\nMejor threshold:", round(best_threshold, 4))
print("Mejor F1:", round(f1[best_index], 4))
# Out:
# Mejor threshold: 0.6346
# Mejor F1: 0.46

# %%
plt.figure(figsize=(6,5))
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.grid()
plt.show()

# %%
fpr, tpr, _ = roc_curve(y_test, y_probs)
auc = roc_auc_score(y_test, y_probs)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {auc:.3f}")
plt.plot([0,1], [0,1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid()
plt.show()

# %%
y_pred_custom = (y_probs > best_threshold).astype(int)
print(classification_report(y_test, y_pred_custom))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85     38012
#            1       0.38      0.55      0.45      7945
#
#     accuracy                           0.77     45957
#    macro avg       0.64      0.68      0.65     45957
# weighted avg       0.81      0.77      0.78     45957
